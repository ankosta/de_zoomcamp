# %% [markdown]
# Q1

# %% [markdown]
# ![H2%20Q1%20GCP.png](attachment:H2%20Q1%20GCP.png)

# %% [markdown]
# ![H2%20Q1%20prefect.png](attachment:H2%20Q1%20prefect.png)

# %% [markdown]
# Q2

# %% [markdown]
# ![H2%20Q2%20cron%20scheduling.png](attachment:H2%20Q2%20cron%20scheduling.png)

# %% [markdown]
# Q3

# %% [markdown]
# ![H2%20Q3%20feb.png](attachment:H2%20Q3%20feb.png)

# %% [markdown]
# ![H2%20Q3%20march.png](attachment:H2%20Q3%20march.png)

# %% [markdown]
# Q4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q6

# %% [markdown]
# ![H2%20Q6%20secret%20block.png](attachment:H2%20Q6%20secret%20block.png)
