# %% [markdown]
# Question 1:
#
#
# SELECT count(*) FROM `caramel-park-375820.dbt_akostina.fact_trips`
# WHERE EXTRACT(year FROM pickup_datetime) in (2019, 2020)
#
# Result: 61 575 573

# %% [markdown]
# Question 2:

# %% [markdown]
# ![H4Q2.png](attachment:H4Q2.png)

# %% [markdown]
# Question 3:
#
# SELECT count(*) FROM `caramel-park-375820.dbt_akostina.stg_fhv_tripdata`
#
# Result: 43 244 693

# %% [markdown]
# Question 4:
#
# SELECT count(*) FROM `caramel-park-375820.dbt_akostina.fact_fhv_trips` WHERE EXTRACT(year FROM pickup_datetime) in (2019)
#
# Result: 22 998 722

# %% [markdown]
# Question 5:

# %% [markdown]
# ![H4Q5.png](attachment:H4Q5.png)
